# %%
import pandas as pd

# %%
prices = pd.read_csv('prices.csv')
prices.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4f8f50f2a4d0> in <module>
# ----> 1 prices = pd.read_csv('prices.csv')
#       2 prices.head()
#
# NameError: name 'pd' is not defined

# %%
joining = pd.read_csv('joining.csv')
joining.head()
# Out:
#   block       street_name       lat        long        town
# 0   309  ANG MO KIO AVE 1  1.365271  103.844819  ANG MO KIO
# 1   216  ANG MO KIO AVE 1  1.366197  103.841505  ANG MO KIO
# 2   211  ANG MO KIO AVE 3  1.369197  103.841667  ANG MO KIO
# 3   202  ANG MO KIO AVE 3  1.368446  103.844516  ANG MO KIO
# 4   235  ANG MO KIO AVE 3  1.366824  103.836491  ANG MO KIO

# %%
prices.merge(joining, how='inner', left_on='STREETreet_name', right_on='street_name')
# Out:
#           month   town_x flat_type block_x       STREETreet_name  \
# 0       2017-01    BEDOK    4 ROOM     765  BEDOK RESERVOIR VIEW
# 1       2017-01    BEDOK    4 ROOM     765  BEDOK RESERVOIR VIEW
# 2       2017-01    BEDOK    4 ROOM     765  BEDOK RESERVOIR VIEW
# 3       2017-01    BEDOK    4 ROOM     765  BEDOK RESERVOIR VIEW
# 4       2017-01    BEDOK    4 ROOM     765  BEDOK RESERVOIR VIEW
# ...         ...      ...       ...     ...                   ...
# 210248  2020-08  HOUGANG    5 ROOM    477B    UPP SERANGOON VIEW
# 210249  2020-08  HOUGANG    5 ROOM    477C    UPP SERANGOON VIEW
# 210250  2020-08  HOUGANG    5 ROOM    477C    UPP SERANGOON VIEW
# 210251  2020-08  HOUGANG    5 ROOM    477C    UPP SERANGOON VIEW
# 210252  2020-08  HOUGANG    5 ROOM    477C    UPP SERANGOON VIEW
#
#        STREETorey_range  floor_area_sqm         flat_model  \
# 0              04 TO 06           105.0  Premium Apartment
# 1              04 TO 06           105.0  Premium Apartment
# ...
